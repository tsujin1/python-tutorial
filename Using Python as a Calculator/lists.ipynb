# %%
squares = [1, 4, 9, 16, 25]
squares
squares[0]
squares[-1]
squares[-3:]
# Out:
# [9, 16, 25]

# %%
squares = [1, 4, 9, 16, 25]
squares[0]
# Out:
# 1

# %%
squares = [1, 4, 9, 16, 25]
squares[-1]
# Out:
# 25

# %%
squares = [1, 4, 9, 16, 25]
squares[-3:]
# Out:
# [9, 16, 25]

# %%
squares = [1, 4, 9, 16, 25]
squares + [36, 49, 64, 81, 100]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
cubes = [1, 8, 27, 65, 125] # something's wrong here
4 ** 3 # the cube of 4 is 64, not 65!
cubes [3] = 64 # replace the wrong value
cubes
# Out:
# [1, 8, 27, 64, 125]

# %%
cubes = [1, 8, 27, 65, 125] 
cubes.append(216)
cubes.append(7 ** 3)
cubes
# Out:
# [1, 8, 27, 65, 125, 216, 343]

# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb # they reference the same object
id(rgb) == id(rgba)
rgba.append("Alph")
rgb
# Out:
# ['Red', 'Green', 'Blue', 'Alph']

# %%
rgb = ["Red", "Green", "Blue"]
rgba = rgb
id(rgb) == id(rgba)
rgba.append("Alph")
rgb
correct_rgba = rgba[:]
correct_rgba[-1] = "Alpha"
correct_rgba
rgb
# Out:
# ['Red', 'Green', 'Blue', 'Alph']

# %%
letters = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
letters
# replace some values
letters[2:5] = ['c', 'd', 'e']
letters
# now we remove them
letters[2:5] = []
letters
# clear the list by replacing all the elements with an empty list
letters[:] = []
letters
# Out:
# []

# %%
letters = ['a','b','c','d']
len(letters)
# Out:
# 4

# %%
a = ['a','b','c']
n = [1, 2, 3]
x = [a, n]
x
x[0]
x[0][1]
# Out:
# 'b'
