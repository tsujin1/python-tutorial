# %%
'spam eggs' # single quotes
# Out:
# 'spam eggs'

# %%
"Paris rabbit got your back :)! Yay!" # double quotes
# Out:
# 'Paris rabbit got your back :)! Yay!'

# %%
'1975' # digits and numerals enclosed in quotes are also strings
# Out:
# '1975'

# %%
'doesn\'t' # use \ ' to escape the single quote..
# Out:
# "doesn't"

# %%
"doesn't" # or use double quote instead
# Out:
# "doesn't"

# %%
'"Yes," they said'
# Out:
# '"Yes," they said'

# %%
"\"Yes,\" they said"
# Out:
# '"Yes," they said'

# %%
'"Isn\'t," they said.'
# Out:
# '"Isn\'t," they said.'

# %%
s = 'First line.\nSecond line.' # \n means newline

# %%
s # without print(), special characters are included in the string
# Out:
# 'First line.\nSecond line.'

# %%
print(s) # with print(), special characters are interpreted, so \n produces new line
# Out:
# First line.
# Second line.

# %%
print('C:\this\name') # here \t means tab, \n means new line
# Out:
# C:	his
# ame

# %%
print(r'C:\this\name') # note the r before the quote
# Out:
# C:\this\name

# %%
print("""\
    Usage: thingy [OPTIONS]
        -h
        -H hostname
    """)
# Out:
#     Usage: thingy [OPTIONS]
#         -h
#         -H hostname

# %%
# 3 times 'un', followed by 'ium'
3 * 'un' + 'ium'
# Out:
# 'unununium'

# %%
'Py' 'thon'
# Out:
# 'Python'

# %%
text = ('Put several strings within parentheses '
        'to have them joined together.')
text
# Out:
# 'Put several strings within parentheses to have them joined together.'

# %%
prefix = 'Py'
prefix + 'thon'
# Out:
# 'Python'

# %%
word = 'Python' # character in position 0
word[0]
# Out:
# 'n'

# %%
word = 'Python' # character in position 5
word[5]
# Out:
# 'n'

# %%
word = 'Python' # last character
word[-1]

# %%
word = 'Python' # second-last character
word[-2]
# Out:
# 'o'

# %%
word = 'Python'
word[-6]
# Out:
# 'P'

# %%
word = 'Python' # characters from position 0 (included) to 2 (excluded)
word[0:2]
# Out:
# 'Py'

# %%
word = 'Python' # characters from position 2 (included) to 5 (excluded)
word[2:5]
# Out:
# 'tho'

# %%
word = 'Python' # character from the beginning to position 2 (excluded)
word[:2]
# Out:
# 'Py'

# %%
word = 'Python' # characters from position 4 (included) to the end
word[4:]
# Out:
# 'on'

# %%
word = 'Python' # characters from the second-last (included) to the end
word[-2:]
# Out:
# 'on'

# %%
word = 'Python'
word[:2] + word[2:]
# Out:
# 'Python'

# %%
word = 'Python'
word[:4] + word[4:]
# Out:
# 'Python'

# %%
| Character      | P  | y  | t  | h  | o  | n      |
| -------------- | -- | -- | -- | -- | -- | ------ |
| Positive index | 0  | 1  | 2  | 3  | 4  | 5      |
| Negative index | -6 | -5 | -4 | -3 | -2 | **-1** |

# %%
word = 'Python'
word[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 2
#       1 word = 'Python'
# ----> 2 word[42]
#
# IndexError: string index out of range

# %%
word = 'Python'
word[4:42]
# Out:
# 'on'

# %%
word = 'Python'
word[42:]
# Out:
# ''

# %%
word = 'Python'
word[0] = 'J'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 2
#       1 word = 'Python'
# ----> 2 word[0] = 'J'
#
# TypeError: 'str' object does not support item assignment

# %%
word = 'Python'
word[2:] = 'py'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 word = 'Python'
# ----> 2 word[2:] = 'py'
#
# TypeError: 'str' object does not support item assignment

# %%
word = 'Python'
'J' + word[1:]
# Out:
# 'Jython'

# %%
word = 'Python'
word[:2] + 'py'
# Out:
# 'Pypy'

# %%
s = 'supercalifragilisticexpialidocious'
len(s)
# Out:
# 34
